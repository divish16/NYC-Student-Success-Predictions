# %%
import pandas as pd
import numpy as np

# %%
file_1 = "2006-2012-school-demographics-and-accountability-snapshot.csv.zip"
file_2 = "2016-2017_Graduation_Outcomes_School.csv"
file_3 = "2017-18__-_2021-22_Demographic_Snapshot.csv"

# %%
demographics_df = pd.read_csv(file_1)
graduation_df = pd.read_csv(file_2)
poverty_df = pd.read_csv(file_3)

# %% [markdown]
# # demographics_df
#
# ## demographics_df contains information regarding gender, race, number of students per grade, number of total students, number of English Language Learners, and some socioeconomic information like percentage of students receiving free lunch.

# %%
demographics_df
# Out:
#           DBN                                              Name  schoolyear  \
# 0      01M015                         P.S. 015 ROBERTO CLEMENTE    20052006
# 1      01M015                         P.S. 015 ROBERTO CLEMENTE    20062007
# 2      01M015                         P.S. 015 ROBERTO CLEMENTE    20072008
# 3      01M015                         P.S. 015 ROBERTO CLEMENTE    20082009
# 4      01M015                         P.S. 015 ROBERTO CLEMENTE    20092010
# ...       ...                                               ...         ...
# 10070  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20072008
# 10071  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20082009
# 10072  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20092010
# 10073  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20102011
# 10074  32K564  BUSHWICK COMMUNITY HIGH SCHOOL                      20112012
#
#       fl_percent  frl_percent  total_enrollment  prek     k grade1 grade2  \
# 0           89.4          NaN               281    15    36     40     33
# 1           89.4          NaN               243    15    29     39     38
# 2           89.4          NaN               261    18    43     39     36
# 3           89.4          NaN               252    17    37     44     32
# 4                        96.5               208    16    40     28     32
# ...          ...          ...               ...   ...   ...    ...    ...
# 10070       85.6          NaN               355   NaN   NaN    NaN    NaN
# 10071       65.2          NaN               383   NaN   NaN    NaN    NaN
# 10072                    89.2               395   NaN   NaN    NaN    NaN
# 10073                    88.2               420   NaN   NaN    NaN    NaN
# 10074        NaN         81.8               382
#
#        ... black_num black_per hispanic_num hispanic_per white_num white_per  \
# 0      ...        74      26.3          189         67.3         5       1.8
# 1      ...        68      28.0          153         63.0         4       1.6
# 2      ...        77      29.5          157         60.2         7       2.7
# 3      ...        75      29.8          149         59.1         7       2.8
# 4      ...        67      32.2          118         56.7         6       2.9
# ...    ...       ...       ...          ...          ...       ...       ...
# 10070  ...       151      42.5          198         55.8         5       1.4
# 10071  ...       132      34.5          245         64.0         2       0.5
# 10072  ...       146      37.0          242         61.3         3       0.8
# 10073  ...       166      39.5          242         57.6         8       1.9
# 10074  ...       137      35.9          235         61.5         7       1.8
#
#       male_num male_per female_num female_per
# 0        158.0     56.2      123.0       43.8
# 1        140.0     57.6      103.0       42.4
# 2        143.0     54.8      118.0       45.2
# 3        149.0     59.1      103.0       40.9
# 4        124.0     59.6       84.0       40.4
# ...        ...      ...        ...        ...
# 10070    181.0     51.0      174.0       49.0
# 10071    206.0     53.8      177.0       46.2
# 10072    199.0     50.4      196.0       49.6
# 10073    209.0     49.8      211.0       50.2
# 10074    169.0     44.2      213.0       55.8
#
# [10075 rows x 38 columns]

# %%
#Number of unique schools in this dataset by school identification code
demographics_df["DBN"].nunique()
# Out:
# 1594

# %%
#Learning count of values per column
demographics_df.count()
# Out:
# DBN                  10075
# Name                 10075
# schoolyear           10075
# fl_percent            8560
# frl_percent           4482
# total_enrollment     10075
# prek                  4712
# k                     5882
# grade1                5881
# grade2                5851
# grade3                5779
# grade4                5741
# grade5                5777
# grade6                4517
# grade7                4203
# grade8                4085
# grade9                3974
# grade10               3846
# grade11               3674
# grade12               3513
# ell_num               9885
# ell_percent           9963
# sped_num              9985
# sped_percent         10075
# ctt_num               8678
# selfcontained_num     9075
# asian_num            10075
# asian_per            10075
# black_num            10075
# black_per            10075
# hispanic_num         10075
# hispanic_per         10075
# white_num            10075
# white_per            10075
# male_num             10034
# male_per             10075
# female_num           10051
# female_per           10075
# dtype: int64

# %% [markdown]
# #### Dropping schools that contain only prek-8 students

# %%
#Dropping prek-grade 8 as our interest is in high schools
drop_df = demographics_df.drop(columns = ["prek","k", "grade1", "grade2","grade3","grade4","grade5","grade6","grade7","grade8"])
drop_df
# Out:
#           DBN                                              Name  schoolyear  \
# 0      01M015                         P.S. 015 ROBERTO CLEMENTE    20052006
# 1      01M015                         P.S. 015 ROBERTO CLEMENTE    20062007
# 2      01M015                         P.S. 015 ROBERTO CLEMENTE    20072008
# 3      01M015                         P.S. 015 ROBERTO CLEMENTE    20082009
# 4      01M015                         P.S. 015 ROBERTO CLEMENTE    20092010
# ...       ...                                               ...         ...
# 10070  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20072008
# 10071  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20082009
# 10072  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20092010
# 10073  32K564                    BUSHWICK COMMUNITY HIGH SCHOOL    20102011
# 10074  32K564  BUSHWICK COMMUNITY HIGH SCHOOL                      20112012
#
#       fl_percent  frl_percent  total_enrollment grade9 grade10 grade11  \
# 0           89.4          NaN               281    NaN     NaN     NaN
# 1           89.4          NaN               243    NaN     NaN     NaN
# 2           89.4          NaN               261    NaN     NaN     NaN
# 3           89.4          NaN               252    NaN     NaN     NaN
# 4                        96.5               208    NaN     NaN     NaN
# ...          ...          ...               ...    ...     ...     ...
# 10070       85.6          NaN               355    NaN     355     NaN
# 10071       65.2          NaN               383    NaN     383     NaN
# 10072                    89.2               395    NaN     395     NaN
# 10073                    88.2               420    NaN     420     NaN
# 10074        NaN         81.8               382            382
#
#       grade12  ...  black_num  black_per  hispanic_num  hispanic_per  \
# 0         NaN  ...         74       26.3           189          67.3
# 1         NaN  ...         68       28.0           153          63.0
# 2         NaN  ...         77       29.5           157          60.2
# 3         NaN  ...         75       29.8           149          59.1
# 4         NaN  ...         67       32.2           118          56.7
# ...       ...  ...        ...        ...           ...           ...
# 10070     NaN  ...        151       42.5           198          55.8
# 10071     NaN  ...        132       34.5           245          64.0
# 10072     NaN  ...        146       37.0           242          61.3
# 10073     NaN  ...        166       39.5           242          57.6
# 10074          ...        137       35.9           235          61.5
#
#       white_num white_per  male_num  male_per  female_num  female_per
# 0             5       1.8     158.0      56.2       123.0        43.8
# 1             4       1.6     140.0      57.6       103.0        42.4
# 2             7       2.7     143.0      54.8       118.0        45.2
# 3             7       2.8     149.0      59.1       103.0        40.9
# 4             6       2.9     124.0      59.6        84.0        40.4
# ...         ...       ...       ...       ...         ...         ...
# 10070         5       1.4     181.0      51.0       174.0        49.0
# 10071         2       0.5     206.0      53.8       177.0        46.2
# 10072         3       0.8     199.0      50.4       196.0        49.6
# 10073         8       1.9     209.0      49.8       211.0        50.2
# 10074         7       1.8     169.0      44.2       213.0        55.8
#
# [10075 rows x 28 columns]

# %%
#Preparing to drop all rows that do not contain any numeric values in the "grade9" through "grade12" columns

#Replacing blank values with NaN
drop_df["grade9"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
drop_df["grade10"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
drop_df["grade11"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
drop_df["grade12"].replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
drop_df.head()
# Out:
#        DBN                                              Name  schoolyear  \
# 0   01M015                         P.S. 015 ROBERTO CLEMENTE    20052006
# 1   01M015                         P.S. 015 ROBERTO CLEMENTE    20062007
# 2   01M015                         P.S. 015 ROBERTO CLEMENTE    20072008
# 3   01M015                         P.S. 015 ROBERTO CLEMENTE    20082009
# 4   01M015                         P.S. 015 ROBERTO CLEMENTE    20092010
# 5   01M015                         P.S. 015 ROBERTO CLEMENTE    20102011
# 6   01M015  P.S. 015 ROBERTO CLEMENTE                           20112012
# 7   01M019                               P.S. 019 ASHER LEVY    20052006
# 8   01M019                               P.S. 019 ASHER LEVY    20062007
# 9   01M019                               P.S. 019 ASHER LEVY    20072008
# 10  01M019                               P.S. 019 ASHER LEVY    20082009
# 11  01M019                               P.S. 019 ASHER LEVY    20092010
# 12  01M019                               P.S. 019 ASHER LEVY    20102011
# 13  01M019  P.S. 019 ASHER LEVY                                 20112012
# 14  01M020                                PS 020 ANNA SILVER    20052006
# 15  01M020                                PS 020 ANNA SILVER    20062007
# 16  01M020                                PS 020 ANNA SILVER    20072008
# 17  01M020                                PS 020 ANNA SILVER    20082009
# 18  01M020                                PS 020 ANNA SILVER    20092010
# 19  01M020                                PS 020 ANNA SILVER    20102011
# 20  01M020  PS 020 ANNA SILVER                                  20112012
# 21  01M034                       PS 034 FRANKLIN D ROOSEVELT    20052006
# 22  01M034                       PS 034 FRANKLIN D ROOSEVELT    20062007
# 23  01M034                       PS 034 FRANKLIN D ROOSEVELT    20072008
# 24  01M034                       PS 034 FRANKLIN D ROOSEVELT    20082009
# 25  01M034                       PS 034 FRANKLIN D ROOSEVELT    20092010
# 26  01M034                       PS 034 FRANKLIN D ROOSEVELT    20102011
# 27  01M034  PS 034 FRANKLIN D ROOSEVELT                         20112012
# 28  01M056                                  JHS 056 CORLEARS    20052006
# 29  01M063                           PS 063 WILLIAM MCKINLEY    20052006
#
#    fl_percent  frl_percent  total_enrollment grade9 grade10 grade11 grade12  \
# 0        89.4          NaN               281    NaN     NaN     NaN     NaN
# 1        89.4          NaN               243    NaN     NaN     NaN     NaN
# 2        89.4          NaN               261    NaN     NaN     NaN     NaN
# 3        89.4          NaN               252    NaN     NaN     NaN     NaN
# 4                     96.5               208    NaN     NaN     NaN     NaN
# 5                     96.5               203    NaN     NaN     NaN     NaN
# 6         NaN         89.4               189    NaN     NaN     NaN     NaN
# 7        61.5          NaN               402    NaN     NaN     NaN     NaN
# 8        61.5          NaN               312    NaN     NaN     NaN     NaN
# 9        61.5          NaN               338    NaN     NaN     NaN     NaN
# 10       61.5          NaN               325    NaN     NaN     NaN     NaN
# 11                    82.0               321    NaN     NaN     NaN     NaN
# 12                    82.0               328    NaN     NaN     NaN     NaN
# 13        NaN         61.5               328    NaN     NaN     NaN     NaN
# 14       92.5          NaN               835    NaN     NaN     NaN     NaN
# 15       92.5          NaN               655    NaN     NaN     NaN     NaN
# 16       92.5          NaN               610    NaN     NaN     NaN     NaN
# 17       92.5          NaN               593    NaN     NaN     NaN     NaN
# 18                    97.1               594    NaN     NaN     NaN     NaN
# 19                    97.1               625    NaN     NaN     NaN     NaN
# 20        NaN         92.5               626    NaN     NaN     NaN     NaN
# 21       76.8          NaN               438    NaN     NaN     NaN     NaN
# 22       76.8          NaN               397    NaN     NaN     NaN     NaN
# 23       76.8          NaN               420      1     NaN     NaN     NaN
# 24         77          NaN               424    NaN     NaN     NaN     NaN
# 25                    93.9               410    NaN     NaN     NaN     NaN
# 26                    99.2               393    NaN     NaN     NaN     NaN
# 27        NaN         99.7               401    NaN     NaN     NaN     NaN
# 28       84.7          NaN               173    NaN     NaN     NaN     NaN
# 29       63.9          NaN               240    NaN     NaN     NaN     NaN
#
#     ...  black_num  black_per  hispanic_num  hispanic_per white_num white_per  \
# 0   ...         74       26.3           189          67.3         5       1.8
# 1   ...         68       28.0           153          63.0         4       1.6
# 2   ...         77       29.5           157          60.2         7       2.7
# 3   ...         75       29.8           149          59.1         7       2.8
# 4   ...         67       32.2           118          56.7         6       2.9
# 5   ...         75       36.9           110          54.2         4       2.0
# 6   ...         63       33.3           109          57.7         4       2.1
# 7   ...        103       25.6           207          51.5        39       9.7
# 8   ...         70       22.4           172          55.1        19       6.1
# 9   ...         72       21.3           186          55.0        22       6.5
# 10  ...         83       25.5           149          45.8        32       9.8
# 11  ...         87       27.1           137          42.7        35      10.9
# 12  ...         89       27.1           155          47.3        31       9.5
# 13  ...         81       24.7           158          48.2        28       8.5
# 14  ...         43        5.1           503          60.2        10       1.2
# 15  ...         36        5.5           414          63.2        10       1.5
# 16  ...         46        7.5           397          65.1        13       2.1
# 17  ...         55        9.3           376          63.4         9       1.5
# 18  ...         59        9.9           355          59.8        12       2.0
# 19  ...         51        8.2           374          59.8        17       2.7
# 20  ...         55        8.8           357          57.0        16       2.6
# 21  ...         88       20.1           313          71.5         6       1.4
# 22  ...         87       21.9           289          72.8         6       1.5
# 23  ...         88       21.0           301          71.7         9       2.1
# 24  ...         87       20.5           295          69.6         9       2.1
# 25  ...         86       21.0           280          68.3         6       1.5
# 26  ...         81       20.6           270          68.7        10       2.5
# 27  ...         90       22.4           275          68.6         8       2.0
# 28  ...         22       12.7            66          38.2         4       2.3
# 29  ...         40       16.7           153          63.8        12       5.0
#
#     male_num  male_per  female_num  female_per
# 0      158.0      56.2       123.0        43.8
# 1      140.0      57.6       103.0        42.4
# 2      143.0      54.8       118.0        45.2
# 3      149.0      59.1       103.0        40.9
# 4      124.0      59.6        84.0        40.4
# 5      113.0      55.7        90.0        44.3
# 6       97.0      51.3        92.0        48.7
# 7      214.0      53.2       188.0        46.8
# 8      157.0      50.3       155.0        49.7
# 9      162.0      47.9       176.0        52.1
# 10     156.0      48.0       169.0        52.0
# 11     154.0      48.0       167.0        52.0
# 12     155.0      47.3       173.0        52.7
# 13     147.0      44.8       181.0        55.2
# 14     389.0      46.6       446.0        53.4
# 15     315.0      48.1       340.0        51.9
# 16     293.0      48.0       317.0        52.0
# 17     286.0      48.2       307.0        51.8
# 18     315.0      53.0       279.0        47.0
# 19     333.0      53.3       292.0        46.7
# 20     330.0      52.7       296.0        47.3
# 21     223.0      50.9       215.0        49.1
# 22     205.0      51.6       192.0        48.4
# 23     210.0      50.0       210.0        50.0
# 24     214.0      50.5       210.0        49.5
# 25     212.0      51.7       198.0        48.3
# 26     199.0      50.6       194.0        49.4
# 27     204.0      50.9       197.0        49.1
# 28      94.0      54.3        79.0        45.7
# 29     132.0      55.0       108.0        45.0
#
# [30 rows x 28 columns]

# %%
#Replacing NaN with a placeholder
drop_df['grade9'].replace(np.nan, "b", inplace=True)
drop_df['grade10'].replace(np.nan, "b", inplace=True)
drop_df['grade11'].replace(np.nan, "b", inplace=True)
drop_df['grade12'].replace(np.nan, "b", inplace=True)

# %%
drop_df.count()
# Out:
# DBN                  10075
# Name                 10075
# schoolyear           10075
# fl_percent            8560
# frl_percent           4482
# total_enrollment     10075
# grade9               10075
# grade10              10075
# grade11              10075
# grade12              10075
# ell_num               9885
# ell_percent           9963
# sped_num              9985
# sped_percent         10075
# ctt_num               8678
# selfcontained_num     9075
# asian_num            10075
# asian_per            10075
# black_num            10075
# black_per            10075
# hispanic_num         10075
# hispanic_per         10075
# white_num            10075
# white_per            10075
# male_num             10034
# male_per             10075
# female_num           10051
# female_per           10075
# dtype: int64

# %%
#Creating a new dataframe that consists only of rows that list a number of students in the grade9 through grade12 columns
drop_df3=drop_df[(drop_df["grade9"] != "b") | (drop_df['grade10'] != "b") | (drop_df['grade11']  != "b") | (drop_df['grade12'] != "b")]

# %%
drop_df3.count()
# Out:
# DBN                  3028
# Name                 3028
# schoolyear           3028
# fl_percent           2557
# frl_percent          1382
# total_enrollment     3028
# grade9               3028
# grade10              3028
# grade11              3028
# grade12              3028
# ell_num              2920
# ell_percent          2969
# sped_num             2963
# sped_percent         3028
# ctt_num              2502
# selfcontained_num    2448
# asian_num            3028
# asian_per            3028
# black_num            3028
# black_per            3028
# hispanic_num         3028
# hispanic_per         3028
# white_num            3028
# white_per            3028
# male_num             3004
# male_per             3028
# female_num           3015
# female_per           3028
# dtype: int64

# %%
drop_df3.head()
# Out:
#         DBN                                              Name  schoolyear  \
# 23   01M034                       PS 034 FRANKLIN D ROOSEVELT    20072008
# 92   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20052006
# 93   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20062007
# 94   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20072008
# 95   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20082009
# 96   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20092010
# 97   01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20102011
# 98   01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES       20112012
# 119  01M515           LOWER EAST SIDE PREPARATORY HIGH SCHOOL    20102011
# 152  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20052006
# 153  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20062007
# 154  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20072008
# 155  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20082009
# 156  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20092010
# 157  01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL    20102011
# 158  01M448  UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                 20112012
# 159  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20052006
# 160  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20062007
# 161  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20072008
# 162  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20082009
# 163  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20092010
# 164  01M450                   EAST SIDE COMMUNITY HIGH SCHOOL    20102011
# 165  01M450  EAST SIDE COMMUNITY HIGH SCHOOL                     20112012
# 166  01M458            SATELLITE ACADEMY HS @ FORSYTHE STREET    20102011
# 167  01M458  SATELLITE ACADEMY HS @ FORSYTHE STREET              20112012
# 168  01M509                      MARTA VALLE SECONDARY SCHOOL    20052006
# 169  01M509                      MARTA VALLE SECONDARY SCHOOL    20062007
# 170  01M509                      MARTA VALLE SECONDARY SCHOOL    20072008
# 171  01M509                      MARTA VALLE SECONDARY SCHOOL    20082009
# 172  01M509                      MARTA VALLE SECONDARY SCHOOL    20092010
#
#     fl_percent  frl_percent  total_enrollment grade9 grade10 grade11 grade12  \
# 23        76.8          NaN               420      1       b       b       b
# 92          99          NaN               294     87      63       b       b
# 93        85.6          NaN               434     92      72      61       b
# 94        99.5          NaN               515    109      82      67      56
# 95        95.3          NaN               470     97      85      60      53
# 96                     69.9               511    109      89      87      55
# 97                     73.3               448    107      85      67      69
# 98         NaN         88.6               422     98      79      80      50
# 119                    95.5               573      b     289     204      80
# 152       71.5          NaN               478    219     118      91      50
# 153       71.5          NaN               533    215     146      95      77
# 154       71.5          NaN               588    244     178      91      75
# 155       60.9          NaN               586    209     196      99      82
# 156                    73.4               532    177     158     129      68
# 157                    76.3               488    120     150     103     115
# 158        NaN         71.8               394    109      97      93      95
# 159       70.6          NaN               501     89      85      74      68
# 160       70.6          NaN               562     91      81      82      66
# 161       70.6          NaN               554     96      88      73      78
# 162       67.7          NaN               546     89      86      80      74
# 163                    79.7               559    100      85      81      84
# 164                    82.2               599    112      92      94      84
# 165        NaN         71.8               598    101      93      77      86
# 166                    81.4               213    105      54      54       b
# 167        NaN         72.8               224    131      49      44       b
# 168       81.5          NaN               558    172     112      32      43
# 169       81.5          NaN               619    187     118      32      57
# 170       81.5          NaN               522    173     115      65      49
# 171       81.5          NaN               441    132     129      65      76
# 172                    92.1               352    103     116      64      69
#
#      ...  black_num  black_per  hispanic_num  hispanic_per white_num  \
# 23   ...         88       21.0           301          71.7         9
# 92   ...        106       36.1           133          45.2        10
# 93   ...        137       31.6           208          47.9        14
# 94   ...        158       30.7           272          52.8        12
# 95   ...        138       29.4           264          56.2        14
# 96   ...        141       27.6           290          56.8        16
# 97   ...        126       28.1           255          56.9         9
# 98   ...        123       29.1           227          53.8         7
# 119  ...         12        2.1            20           3.5         3
# 152  ...         72       15.1           217          45.4        21
# 153  ...         93       17.4           252          47.3        22
# 154  ...        115       19.6           278          47.3        26
# 155  ...        138       23.5           280          47.8        25
# 156  ...        144       27.1           247          46.4        25
# 157  ...        128       26.2           232          47.5        18
# 158  ...         89       22.6           181          45.9         9
# 159  ...        138       27.5           299          59.7        28
# 160  ...        161       28.6           337          60.0        30
# 161  ...        149       26.9           335          60.5        29
# 162  ...        145       26.6           326          59.7        33
# 163  ...        151       27.0           321          57.4        31
# 164  ...        152       25.4           339          56.6        58
# 165  ...        143       23.9           331          55.4        62
# 166  ...         59       27.7           136          63.8         8
# 167  ...         77       34.4           133          59.4         8
# 168  ...         76       13.6           371          66.5        13
# 169  ...        117       18.9           410          66.2        10
# 170  ...         90       17.2           361          69.2        10
# 171  ...         78       17.7           303          68.7         8
# 172  ...         65       18.5           239          67.9         7
#
#     white_per  male_num  male_per  female_num  female_per
# 23        2.1     210.0      50.0       210.0        50.0
# 92        3.4     160.0      54.4       134.0        45.6
# 93        3.2     241.0      55.5       193.0        44.5
# 94        2.3     281.0      54.6       234.0        45.4
# 95        3.0     264.0      56.2       206.0        43.8
# 96        3.1     297.0      58.1       214.0        41.9
# 97        2.0     267.0      59.6       181.0        40.4
# 98        1.7     259.0      61.4       163.0        38.6
# 119       0.5     322.0      56.2       251.0        43.8
# 152       4.4     247.0      51.7       231.0        48.3
# 153       4.1     258.0      48.4       275.0        51.6
# 154       4.4     300.0      51.0       288.0        49.0
# 155       4.3     307.0      52.4       279.0        47.6
# 156       4.7     286.0      53.8       246.0        46.2
# 157       3.7     275.0      56.4       213.0        43.6
# 158       2.3     226.0      57.4       168.0        42.6
# 159       5.6     244.0      48.7       257.0        51.3
# 160       5.3     296.0      52.7       266.0        47.3
# 161       5.2     288.0      52.0       266.0        48.0
# 162       6.0     285.0      52.2       261.0        47.8
# 163       5.5     299.0      53.5       260.0        46.5
# 164       9.7     319.0      53.3       280.0        46.7
# 165      10.4     327.0      54.7       271.0        45.3
# 166       3.8      96.0      45.1       117.0        54.9
# 167       3.6      97.0      43.3       127.0        56.7
# 168       2.3     298.0      53.4       260.0        46.6
# 169       1.6     307.0      49.6       312.0        50.4
# 170       1.9     268.0      51.3       254.0        48.7
# 171       1.8     230.0      52.2       211.0        47.8
# 172       2.0     178.0      50.6       174.0        49.4
#
# [30 rows x 28 columns]

# %% [markdown]
# #### Combining frl (free/reduced lunch) and fl (free lunch) columns

# %%
#Combine frl and fl

#Check to see whether any rows have figures in BOTH frl and fl columns

#Replace empty values with np.nan
drop_df3["fl_percent"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
drop_df3["frl_percent"].replace(r'^\s*$', np.nan, regex=True, inplace=True)
# Out:
# C:\Users\David\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
drop_df3.dtypes
# Out:
# DBN                   object
# Name                  object
# schoolyear             int64
# fl_percent            object
# frl_percent          float64
# total_enrollment       int64
# grade9                object
# grade10               object
# grade11               object
# grade12               object
# ell_num              float64
# ell_percent          float64
# sped_num             float64
# sped_percent         float64
# ctt_num               object
# selfcontained_num     object
# asian_num              int64
# asian_per            float64
# black_num              int64
# black_per            float64
# hispanic_num           int64
# hispanic_per         float64
# white_num              int64
# white_per            float64
# male_num             float64
# male_per             float64
# female_num           float64
# female_per           float64
# dtype: object

# %%
#Convert fl_percent from string to float
drop_df3['fl_percent'] = drop_df3['fl_percent'].astype(float)
# Out:
# C:\Users\David\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Check to see if there are any rows with numeric values in both fl_percent and frl_percent
drop_df3[(drop_df3["fl_percent"] >0 ) & (drop_df3["frl_percent"] >0)]
# Out:
# Empty DataFrame
# Columns: [DBN, Name, schoolyear, fl_percent, frl_percent, total_enrollment, grade9, grade10, grade11, grade12, ell_num, ell_percent, sped_num, sped_percent, ctt_num, selfcontained_num, asian_num, asian_per, black_num, black_per, hispanic_num, hispanic_per, white_num, white_per, male_num, male_per, female_num, female_per]
# Index: []
#
# [0 rows x 28 columns]

# %%
#Combine fl_percent and frl_percent columns
drop_df3['frl_combined_percent'] = drop_df3[['fl_percent', 'frl_percent']].bfill(axis=1).iloc[:, 0]
# Out:
# C:\Users\David\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
drop_df3.head()
# Out:
#        DBN                                           Name  schoolyear  \
# 23  01M034                    PS 034 FRANKLIN D ROOSEVELT    20072008
# 92  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20052006
# 93  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20062007
# 94  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20072008
# 95  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20082009
#
#     fl_percent  frl_percent  total_enrollment grade9 grade10 grade11 grade12  \
# 23        76.8          NaN               420      1       b       b       b
# 92        99.0          NaN               294     87      63       b       b
# 93        85.6          NaN               434     92      72      61       b
# 94        99.5          NaN               515    109      82      67      56
# 95        95.3          NaN               470     97      85      60      53
#
#     ...  black_per  hispanic_num  hispanic_per  white_num white_per male_num  \
# 23  ...       21.0           301          71.7          9       2.1    210.0
# 92  ...       36.1           133          45.2         10       3.4    160.0
# 93  ...       31.6           208          47.9         14       3.2    241.0
# 94  ...       30.7           272          52.8         12       2.3    281.0
# 95  ...       29.4           264          56.2         14       3.0    264.0
#
#     male_per  female_num  female_per  frl_combined_percent
# 23      50.0       210.0        50.0                  76.8
# 92      54.4       134.0        45.6                  99.0
# 93      55.5       193.0        44.5                  85.6
# 94      54.6       234.0        45.4                  99.5
# 95      56.2       206.0        43.8                  95.3
#
# [5 rows x 29 columns]

# %%
drop_df4 = drop_df3.drop(columns = ["fl_percent","frl_percent"])

# %%
drop_df4
# Out:
#        DBN                                           Name  schoolyear  \
# 23  01M034                    PS 034 FRANKLIN D ROOSEVELT    20072008
# 92  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20052006
# 93  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20062007
# 94  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20072008
# 95  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES    20082009
#
#     total_enrollment grade9 grade10 grade11 grade12  ell_num  ell_percent  \
# 23               420      1       b       b       b     35.0          8.3
# 92               294     87      63       b       b     29.0          9.9
# 93               434     92      72      61       b     46.0         10.6
# 94               515    109      82      67      56     52.0         10.1
# 95               470     97      85      60      53     50.0         10.6
#
#     ...  black_per  hispanic_num hispanic_per white_num  white_per  male_num  \
# 23  ...       21.0           301         71.7         9        2.1     210.0
# 92  ...       36.1           133         45.2        10        3.4     160.0
# 93  ...       31.6           208         47.9        14        3.2     241.0
# 94  ...       30.7           272         52.8        12        2.3     281.0
# 95  ...       29.4           264         56.2        14        3.0     264.0
#
#     male_per  female_num  female_per  frl_combined_percent
# 23      50.0       210.0        50.0                  76.8
# 92      54.4       134.0        45.6                  99.0
# 93      55.5       193.0        44.5                  85.6
# 94      54.6       234.0        45.4                  99.5
# 95      56.2       206.0        43.8                  95.3
#
# [5 rows x 27 columns]

# %%
drop_df4.columns
# Out:
# Index(['DBN', 'Name', 'schoolyear', 'total_enrollment', 'grade9', 'grade10',
#        'grade11', 'grade12', 'ell_num', 'ell_percent', 'sped_num',
#        'sped_percent', 'ctt_num', 'selfcontained_num', 'asian_num',
#        'asian_per', 'black_num', 'black_per', 'hispanic_num', 'hispanic_per',
#        'white_num', 'white_per', 'male_num', 'male_per', 'female_num',
#        'female_per', 'frl_combined_percent'],
#       dtype='object')

# %%
drop_df4["DBN"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6724/1559150763.py in <module>
# ----> 1 drop_df4["DBN"].nunique()
#
# NameError: name 'drop_df4' is not defined

# %% [markdown]
# ## graduation_df

# %%
graduation_df.columns
# Out:
# Index(['DBN', 'School Name', 'Demographic Category', 'Demographic Variable',
#        'Cohort Year', 'Cohort', 'Total Cohort #', 'Total Grads #',
#        'Total Grads % of cohort', 'Total Regents #',
#        'Total Regents % of cohort', 'Total Regents % of grads',
#        'Advanced Regents #', 'Advanced Regents % of cohort',
#        'Advanced Regents % of grads', 'Regents w/o Advanced #',
#        'Regents w/o Advanced % of cohort', 'Regents w/o Advanced % of grads',
#        'Local #', 'Local % of cohort', 'Local % of grads', 'Still Enrolled #',
#        'Still Enrolled % of cohort', 'Dropped Out #',
#        'Dropped Out % of cohort', 'SACC (IEP Diploma) #',
#        'SACC (IEP Diploma) % of cohort', 'TASC (GED) #',
#        'TASC (GED) % of cohort'],
#       dtype='object')

# %%
graduation_df.head(30)
# Out:
#        DBN                 School Name Demographic Category  \
# 0   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 1   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 2   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 3   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 4   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 5   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 6   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 7   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 8   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 9   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 10  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 11  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 12  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 13  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 14  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 15  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 16  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 17  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 18  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 19  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 20  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 21  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 22  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 23  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 24  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 25  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 26  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 27  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 28  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 29  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
#
#    Demographic Variable  Cohort Year         Cohort  Total Cohort #  \
# 0          All Students         2013  4 year August              36
# 1          All Students         2012  4 year August              44
# 2          All Students         2011  4 year August              73
# 3          All Students         2010  4 year August              61
# 4          All Students         2009  4 year August              85
# 5          All Students         2008  4 year August              70
# 6          All Students         2007  4 year August              77
# 7          All Students         2006  4 year August              78
# 8          All Students         2005  4 year August              64
# 9          All Students         2013    4 year June              36
# 10         All Students         2012    4 year June              44
# 11         All Students         2011    4 year June              73
# 12         All Students         2010    4 year June              61
# 13         All Students         2009    4 year June              85
# 14         All Students         2008    4 year June              70
# 15         All Students         2007    4 year June              77
# 16         All Students         2006    4 year June              78
# 17         All Students         2005    4 year June              64
# 18         All Students         2004    4 year June              55
# 19         All Students         2003    4 year June               5
# 20         All Students         2012  5 year August              41
# 21         All Students         2011  5 year August              68
# 22         All Students         2010  5 year August              55
# 23         All Students         2009  5 year August              82
# 24         All Students         2008  5 year August              68
# 25         All Students         2007  5 year August              77
# 26         All Students         2006  5 year August              71
# 27         All Students         2012    5 year June              41
# 28         All Students         2011    5 year June              68
# 29         All Students         2010    5 year June              55
#
#     Total Grads #  Total Grads % of cohort  Total Regents #  ...  \
# 0            25.0                     69.4             23.0  ...
# 1            24.0                     54.5             20.0  ...
# 2            46.0                     63.0             41.0  ...
# 3            26.0                     42.6             26.0  ...
# 4            49.0                     57.6             44.0  ...
# 5            36.0                     51.4             30.0  ...
# 6            45.0                     58.4             29.0  ...
# 7            44.0                     56.4             37.0  ...
# 8            44.0                     68.8             27.0  ...
# 9            24.0                     66.7             23.0  ...
# 10           23.0                     52.3             19.0  ...
# 11           46.0                     63.0             41.0  ...
# 12           24.0                     39.3             24.0  ...
# 13           47.0                     55.3             42.0  ...
# 14           35.0                     50.0             29.0  ...
# 15           41.0                     53.2             28.0  ...
# 16           43.0                     55.1             36.0  ...
# 17           43.0                     67.2             27.0  ...
# 18           37.0                     67.3             17.0  ...
# 19            0.0                      0.0              0.0  ...
# 20           28.0                     68.3             22.0  ...
# 21           48.0                     70.6             42.0  ...
# 22           28.0                     50.9             27.0  ...
# 23           57.0                     69.5             50.0  ...
# 24           40.0                     58.8             34.0  ...
# 25           51.0                     66.2             30.0  ...
# 26           44.0                     62.0             36.0  ...
# 27           28.0                     68.3             22.0  ...
# 28           48.0                     70.6             42.0  ...
# 29           28.0                     50.9             27.0  ...
#
#     Local % of cohort  Local % of grads  Still Enrolled #  \
# 0                 5.6               8.0               3.0
# 1                 9.1              16.7              10.0
# 2                 6.8              10.9              18.0
# 3                 0.0               0.0              18.0
# 4                 5.9              10.2              28.0
# 5                 8.6              16.7              18.0
# 6                20.8              35.6              22.0
# 7                 9.0              15.9              15.0
# 8                26.6              38.6               8.0
# 9                 2.8               4.2               4.0
# 10                9.1              17.4              11.0
# 11                6.8              10.9              18.0
# 12                0.0               0.0              20.0
# 13                5.9              10.6              30.0
# 14                8.6              17.1              19.0
# 15               16.9              31.7              25.0
# 16                9.0              16.3              16.0
# 17               25.0              37.2               9.0
# 18               36.4              54.1              15.0
# 19                0.0               NaN               4.0
# 20               14.6              21.4               1.0
# 21                8.8              12.5               6.0
# 22                1.8               3.6               7.0
# 23                8.5              12.3              10.0
# 24                8.8              15.0              13.0
# 25               27.3              41.2               2.0
# 26               11.3              18.2               0.0
# 27               14.6              21.4               1.0
# 28                8.8              12.5               6.0
# 29                1.8               3.6               7.0
#
#     Still Enrolled % of cohort  Dropped Out #  Dropped Out % of cohort  \
# 0                          8.3            7.0                     19.4
# 1                         22.7           10.0                     22.7
# 2                         24.7            7.0                      9.6
# 3                         29.5           17.0                     27.9
# 4                         32.9            8.0                      9.4
# 5                         25.7           13.0                     18.6
# 6                         28.6            5.0                      6.5
# 7                         19.2           11.0                     14.1
# 8                         12.5            9.0                     14.1
# 9                         11.1            7.0                     19.4
# 10                        25.0           10.0                     22.7
# 11                        24.7            7.0                      9.6
# 12                        32.8           17.0                     27.9
# 13                        35.3            8.0                      9.4
# 14                        27.1           13.0                     18.6
# 15                        32.5            5.0                      6.5
# 16                        20.5           11.0                     14.1
# 17                        14.1            9.0                     14.1
# 18                        27.3            3.0                      5.5
# 19                        80.0            1.0                     20.0
# 20                         2.4           12.0                     29.3
# 21                         8.8           14.0                     20.6
# 22                        12.7           18.0                     32.7
# 23                        12.2           15.0                     18.3
# 24                        19.1           12.0                     17.6
# 25                         2.6           16.0                     20.8
# 26                         0.0           19.0                     26.8
# 27                         2.4           12.0                     29.3
# 28                         8.8           14.0                     20.6
# 29                        12.7           18.0                     32.7
#
#     SACC (IEP Diploma) #  SACC (IEP Diploma) % of cohort  TASC (GED) #  \
# 0                    NaN                             NaN           NaN
# 1                    NaN                             NaN           NaN
# 2                    NaN                             NaN           NaN
# 3                    NaN                             NaN           NaN
# 4                    NaN                             NaN           NaN
# 5                    NaN                             NaN           NaN
# 6                    NaN                             NaN           NaN
# 7                    NaN                             NaN           NaN
# 8                    NaN                             NaN           NaN
# 9                    NaN                             NaN           NaN
# 10                   NaN                             NaN           NaN
# 11                   NaN                             NaN           NaN
# 12                   NaN                             NaN           NaN
# 13                   NaN                             NaN           NaN
# 14                   NaN                             NaN           NaN
# 15                   NaN                             NaN           NaN
# 16                   NaN                             NaN           NaN
# 17                   NaN                             NaN           NaN
# 18                   NaN                             NaN           NaN
# 19                   NaN                             NaN           NaN
# 20                   NaN                             NaN           NaN
# 21                   NaN                             NaN           NaN
# 22                   NaN                             NaN           NaN
# 23                   NaN                             NaN           NaN
# 24                   NaN                             NaN           NaN
# 25                   NaN                             NaN           NaN
# 26                   NaN                             NaN           NaN
# 27                   NaN                             NaN           NaN
# 28                   NaN                             NaN           NaN
# 29                   NaN                             NaN           NaN
#
#     TASC (GED) % of cohort
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
#
# [30 rows x 29 columns]

# %%
graduation_df["DBN"].nunique()
# Out:
# 544

# %%
graduation_df.count()
# Out:
# DBN                                 255717
# School Name                         255717
# Demographic Category                255717
# Demographic Variable                255717
# Cohort Year                         255717
# Cohort                              255717
# Total Cohort #                      255717
# Total Grads #                       180437
# Total Grads % of cohort             180437
# Total Regents #                     180437
# Total Regents % of cohort           180437
# Total Regents % of grads            179040
# Advanced Regents #                  180437
# Advanced Regents % of cohort        180437
# Advanced Regents % of grads         179040
# Regents w/o Advanced #              180437
# Regents w/o Advanced % of cohort    180437
# Regents w/o Advanced % of grads     179040
# Local #                             180437
# Local % of cohort                   180437
# Local % of grads                    179040
# Still Enrolled #                    180437
# Still Enrolled % of cohort          180437
# Dropped Out #                       180437
# Dropped Out % of cohort             180437
# SACC (IEP Diploma) #                     0
# SACC (IEP Diploma) % of cohort           0
# TASC (GED) #                             0
# TASC (GED) % of cohort                   0
# dtype: int64

# %%
# Dropping SACC (IEP Diploma) #, SACC (IEP Diploma) % of cohort, TASC (GED) #, TASC (GED) % of cohort, as these contain no values

graduation_df2=graduation_df.drop(columns=['SACC (IEP Diploma) #',"SACC (IEP Diploma) % of cohort",'TASC (GED) #',
       'TASC (GED) % of cohort'])

# %%
#Take an average of all the numeric values for each school

graduation_df2.dtypes
# Out:
# DBN                                  object
# School Name                          object
# Demographic Category                 object
# Demographic Variable                 object
# Cohort Year                           int64
# Cohort                               object
# Total Cohort #                        int64
# Total Grads #                       float64
# Total Grads % of cohort             float64
# Total Regents #                     float64
# Total Regents % of cohort           float64
# Total Regents % of grads            float64
# Advanced Regents #                  float64
# Advanced Regents % of cohort        float64
# Advanced Regents % of grads         float64
# Regents w/o Advanced #              float64
# Regents w/o Advanced % of cohort    float64
# Regents w/o Advanced % of grads     float64
# Local #                             float64
# Local % of cohort                   float64
# Local % of grads                    float64
# Still Enrolled #                    float64
# Still Enrolled % of cohort          float64
# Dropped Out #                       float64
# Dropped Out % of cohort             float64
# dtype: object

# %%
#graduation_df_groupby=graduation_df2.groupby('DBN')['Total Cohort #'].mean(), graduation_df2.groupby('DBN')['Total Grads #'].mean()}]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6724/2129834526.py in <module>
# ----> 1 graduation_df_groupby=[{graduation_df2.groupby('DBN')['Total Cohort #'].mean()}, {graduation_df2.groupby('DBN')['Total Grads #'].mean()}]
#
# TypeError: unhashable type: 'Series'

# %%
total_cohort = graduation_df2.groupby(["DBN"]).mean()["Total Cohort #"]
total_grads = graduation_df2.groupby(["DBN"]).mean()["Total Grads #"]
total_grads_perc = graduation_df2.groupby(["DBN"]).mean()["Total Grads % of cohort"]

# %%
per_school_summary_df = pd.DataFrame({
    "Total Number in Cohort": total_cohort,
    "Total Number of Grads": total_grads,
    "Percentage of Grads per Cohort": total_grads_perc})

# Need to fill this out with other desired columns

# %%
per_school_summary_df
# Out:
#         Total Number in Cohort  Total Number of Grads  \
# DBN
# 01M292               24.731419              21.324257
# 01M448               38.534039              34.458414
# 01M450               34.300912              35.620332
# 01M458               41.509174              11.857627
# 01M509               31.965300              23.456790
# ...                        ...                    ...
# 32K549               42.149660              41.804455
# 32K552               38.360197              33.275610
# 32K554               17.869023              21.878543
# 32K556               43.216696              37.249389
# 32K564               67.926829              17.362150
#
#         Percentage of Grads per Cohort
# DBN
# 01M292                       61.206188
# 01M448                       74.871180
# 01M450                       79.479668
# 01M458                       19.926780
# 01M509                       56.813374
# ...                                ...
# 32K549                       68.264604
# 32K552                       61.766829
# 32K554                       94.307692
# 32K556                       63.953545
# 32K564                       18.217523
#
# [544 rows x 3 columns]

# %%
#graduation_df2 can be joined with drop_df4 on DBN

# %% [markdown]
# #poverty_df

# %%
poverty_df
# Out:
#          DBN                        School Name     Year  Total Enrollment  \
# 0     01M015          P.S. 015 Roberto Clemente  2017-18               190
# 1     01M015          P.S. 015 Roberto Clemente  2018-19               174
# 2     01M015          P.S. 015 Roberto Clemente  2019-20               190
# 3     01M015          P.S. 015 Roberto Clemente  2020-21               193
# 4     01M015          P.S. 015 Roberto Clemente  2021-22               179
# ...      ...                                ...      ...               ...
# 9246  84X730  Bronx Charter School for the Arts  2017-18               314
# 9247  84X730  Bronx Charter School for the Arts  2018-19               430
# 9248  84X730  Bronx Charter School for the Arts  2019-20               523
# 9249  84X730  Bronx Charter School for the Arts  2020-21               626
# 9250  84X730  Bronx Charter School for the Arts  2021-22               598
#
#       Grade 3K  Grade PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  \
# 0            0                              17       28       32       33
# 1            0                              13       20       33       30
# 2            0                              14       29       28       38
# 3            0                              17       29       29       27
# 4            0                              15       30       26       24
# ...        ...                             ...      ...      ...      ...
# 9246         0                               0       50       51       54
# 9247         0                               0       49       54       49
# 9248         0                               0       51       50       53
# 9249         0                               0       38       52       53
# 9250         0                               0       52       44       54
#
#       Grade 3  ...  % White  # Missing Race/Ethnicity Data  \
# 0          23  ...    0.032                              0
# 1          30  ...    0.034                              0
# 2          33  ...    0.047                              0
# 3          30  ...    0.057                              0
# 4          22  ...    0.067                              0
# ...       ...  ...      ...                            ...
# 9246       51  ...    0.003                              0
# 9247       54  ...    0.007                              0
# 9248       52  ...    0.010                              0
# 9249       55  ...    0.006                              1
# 9250       55  ...    0.005                              2
#
#       % Missing Race/Ethnicity Data  # Students with Disabilities  \
# 0                             0.000                            49
# 1                             0.000                            39
# 2                             0.000                            46
# 3                             0.000                            44
# 4                             0.000                            38
# ...                             ...                           ...
# 9246                          0.000                            68
# 9247                          0.000                           103
# 9248                          0.000                           117
# 9249                          0.002                           152
# 9250                          0.003                           133
#
#       % Students with Disabilities  # English Language Learners  \
# 0                            0.258                            8
# 1                            0.224                            8
# 2                            0.242                           17
# 3                            0.228                           21
# 4                            0.212                           11
# ...                            ...                          ...
# 9246                         0.217                           57
# 9247                         0.240                           71
# 9248                         0.224                           69
# 9249                         0.243                           78
# 9250                         0.222                           79
#
#       % English Language Learners  # Poverty  % Poverty  Economic Need Index
# 0                           0.042        161      84.7%                89.0%
# 1                           0.046        147      84.5%                88.8%
# 2                           0.089        155      81.6%                86.7%
# 3                           0.109        161      83.4%                86.4%
# 4                           0.061        150      83.8%                87.9%
# ...                           ...        ...        ...                  ...
# 9246                        0.182        258      82.2%                89.1%
# 9247                        0.165        363      84.4%                88.8%
# 9248                        0.132        453      86.6%                89.2%
# 9249                        0.125        547      87.4%                88.9%
# 9250                        0.132        540      90.3%                90.3%
#
# [9251 rows x 44 columns]

# %%
poverty_df.columns
# Out:
# Index(['DBN', 'School Name', 'Year', 'Total Enrollment', 'Grade 3K',
#        'Grade PK (Half Day & Full Day)', 'Grade K', 'Grade 1', 'Grade 2',
#        'Grade 3', 'Grade 4', 'Grade 5', 'Grade 6', 'Grade 7', 'Grade 8',
#        'Grade 9', 'Grade 10', 'Grade 11', 'Grade 12', '# Female', '% Female',
#        '# Male', '% Male', '# Asian', '% Asian', '# Black', '% Black',
#        '# Hispanic', '% Hispanic', '# Multi-Racial', '% Multi-Racial',
#        '# Native American', '% Native American', '# White', '% White',
#        '# Missing Race/Ethnicity Data', '% Missing Race/Ethnicity Data',
#        '# Students with Disabilities', '% Students with Disabilities',
#        '# English Language Learners', '% English Language Learners',
#        '# Poverty', '% Poverty', 'Economic Need Index'],
#       dtype='object')

# %%
#Run same process as on demographics_df to remove schools that have only students in prek-8

# %%
poverty_df["DBN"].nunique()
# Out:
# 1882

# %%
poverty_df.dtypes
# Out:
# DBN                                object
# School Name                        object
# Year                               object
# Total Enrollment                    int64
# Grade 3K                            int64
# Grade PK (Half Day & Full Day)      int64
# Grade K                             int64
# Grade 1                             int64
# Grade 2                             int64
# Grade 3                             int64
# Grade 4                             int64
# Grade 5                             int64
# Grade 6                             int64
# Grade 7                             int64
# Grade 8                             int64
# Grade 9                             int64
# Grade 10                            int64
# Grade 11                            int64
# Grade 12                            int64
# # Female                            int64
# % Female                          float64
# # Male                              int64
# % Male                            float64
# # Asian                             int64
# % Asian                           float64
# # Black                             int64
# % Black                           float64
# # Hispanic                          int64
# % Hispanic                        float64
# # Multi-Racial                      int64
# % Multi-Racial                    float64
# # Native American                   int64
# % Native American                 float64
# # White                             int64
# % White                           float64
# # Missing Race/Ethnicity Data       int64
# % Missing Race/Ethnicity Data     float64
# # Students with Disabilities        int64
# % Students with Disabilities      float64
# # English Language Learners         int64
# % English Language Learners       float64
# # Poverty                          object
# % Poverty                          object
# Economic Need Index                object
# dtype: object

# %%
#Convert # Poverty, % Poverty, and Economic Need Index to numeric dtypes

# %%
#Run same process as on graduation_df to average numeric

# %% [markdown]
# ### poverty_df can be joined with demographics_df and graduation_df on DBN

# %% [markdown]
# ### in addition, we could join demographics_df and graduation_df on DBN and year (after cleaning year column) to correlate the student success and graduation stats there, to create Tableau visualizations where the user could select the year
